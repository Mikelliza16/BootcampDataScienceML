# %%
import numpy as np
import pandas as pd

import os


os.getcwd()
# Out:
# 'c:\\Users\\usuario\\Desktop\\DataScience\\MIKEL_TEMARIO\\MIKEL_TEMARIO_REPO\\2-Data_analysis\\EDA'

# %%
print("Archivos en la carpeta actual:")
print(os.listdir())
# Out:
# Archivos en la carpeta actual:
# ['0-Enunciado_EDA.ipynb', 'bike_buyers_dataset.csv', 'Info para el Proyecto - Analisis de Supermercado.docx', 'Info para el Proyecto - Bike Buyers.docx', 'Info para el Proyecto - Students Performance.docx', 'Info para el Proyecto - Volcanes y Población.docx', 'lifts.csv', 'Proyecto EDA Analisis de Supermercado.ipynb', 'Proyecto EDA Bike Buyers 1000.ipynb', 'Proyecto EDA Ski y Avalanchas.ipynb', 'Proyecto EDA Students Performance.ipynb', 'Proyecto EDA Volcanes y Población.ipynb', 'Student_performance_dataset.csv', 'SuperMarket Analysis.csv', 'SuperMarket Analysis.ipynb', 'Ventas_supermercado.csv', 'version2_avalanche_accidents_all_switzerland_since_1970.csv', 'volcano_db.csv', '~$fo para el Proyecto - Volcanes y Población.docx']

# %%
import pandas as pd

df = pd.read_csv("bike_buyers_dataset.csv")
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    993 non-null    object
#  2   Gender            989 non-null    object
#  3   Income            994 non-null    float64
#  4   Children          992 non-null    float64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        996 non-null    object
#  8   Cars              991 non-null    float64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               992 non-null    float64
#  12  Purchased Bike    1000 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 101.7+ KB

# %%
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...
