# %% [markdown]
# # Pruebas rápidas — Bike Buyers

# %%
from src.utils.data_loading import load_bike_buyers
CSV_PATH = 'src/data/Bike_Buyers.csv'
df = load_bike_buyers(CSV_PATH)
df.head()
