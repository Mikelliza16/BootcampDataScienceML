# %% [markdown]
# # Ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
df = pd.read_csv('Pokemon.csv')

df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# ..       ...    ...    ...        ...
# 146       50     50      1      False
# 147       70     70      2      False
# 148      100     80      3      False
# 149       90    130      1       True
# 150      100    100      1      False
#
# [151 rows x 13 columns]

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
df.head(10)
# Out:
#     #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1   2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2   3    Venusaur  Grass  Poison    525  80      82       83      100
# 3   4  Charmander   Fire     NaN    309  39      52       43       60
# 4   5  Charmeleon   Fire     NaN    405  58      64       58       80
# 5   6   Charizard   Fire  Flying    534  78      84       78      109
# 6   7    Squirtle  Water     NaN    314  44      48       65       50
# 7   8   Wartortle  Water     NaN    405  59      63       80       65
# 8   9   Blastoise  Water     NaN    530  79      83      100       85
# 9  10    Caterpie    Bug     NaN    195  45      30       35       20
#
#    Sp. Def  Speed  Stage  Legendary
# 0       65     45      1      False
# 1       80     60      2      False
# 2      100     80      3      False
# 3       50     65      1      False
# 4       65     80      2      False
# 5       85    100      3      False
# 6       64     43      1      False
# 7       80     58      2      False
# 8      105     78      3      False
# 9       20     45      1      False

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del función en el parámetro llamado data

# %%
# Crear un scatter plot con regresión lineal
sns.lmplot(x = 'Attack', y = 'Defense', data = df)

# Mostrar el gráfico
plt.show()

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso

# %%
# Scatter plot sin línea de regresión
sns.lmplot(x = 'Attack', y = 'Defense', data = df, fit_reg = False)

plt.show()

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage

# %%
# Scatter plot sin línea de regresión y color 'Stage'
sns.lmplot(x = 'Attack', y = 'Defense', data = df, fit_re = False, hue ='Stage')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Scatter plot sin línea de regresión y color 'Stage'
# ----> 2 sns.lmplot(x = 'Attack', y = 'Defense', data = df, fit_re = False, hue ='Stage')
#       5 plt.show()
#
# TypeError: lmplot() got an unexpected keyword argument 'fit_re'

# %%
# 8. Limita el eje x entre 20 y 100

# %%
# Scatter plot sin línea de regresión y color 'Stage'
sns.lmplot(x = 'Attack', y = 'Defense', data = df, fit_reg = False, hue = 'Stage')

# Limitar el eje X entre 20 y 100
plt.xlim(20, 100)


plt.show()

# %%
# 9. Dibuja un diagrama de cajas con el dataframe

# %%
# Diagrama de cajas con el DataFrame
sns.boxplot(x = df["Attack"])

plt.show()

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
# Eliminar las columnas Total, Stage y Legendary
df = df.drop(['Total', 'Stage', 'Legendary'], axis = 1)

# Volver a dibujar el diagrama de cajas
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 2
#       1 # Eliminar las columnas Total, Stage y Legendary
# ----> 2 df = df.drop(['Total', 'Stage', 'Legendary'], axis = 1)
#       4 # Volver a dibujar el diagrama de cajas
#       5 plt.figure(figsize=(12,6))
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Total', 'Stage', 'Legendary'] not found in axis"

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
num_tipos = df['Type 1'].nunique()
num_tipos
# Out:
# 15

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
df = df.loc[df['Type 1'].isin(['Grass', 'Fire', 'Water'])]

df
# Out:
#        #        Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur  Grass    Poison   45      49       49       65       65
# 1      2     Ivysaur  Grass    Poison   60      62       63       80       80
# 2      3    Venusaur  Grass    Poison   80      82       83      100      100
# 3      4  Charmander   Fire       NaN   39      52       43       60       50
# 4      5  Charmeleon   Fire       NaN   58      64       58       80       65
# 5      6   Charizard   Fire    Flying   78      84       78      109       85
# 6      7    Squirtle  Water       NaN   44      48       65       50       64
# 7      8   Wartortle  Water       NaN   59      63       80       65       80
# 8      9   Blastoise  Water       NaN   79      83      100       85      105
# 36    37      Vulpix   Fire       NaN   38      41       40       50       65
# 37    38   Ninetales   Fire       NaN   73      76       75       81      100
# 42    43      Oddish  Grass    Poison   45      50       55       75       65
# 43    44       Gloom  Grass    Poison   60      65       70       85       75
# 44    45   Vileplume  Grass    Poison   75      80       85      110       90
# 53    54     Psyduck  Water       NaN   50      52       48       65       50
# 54    55     Golduck  Water       NaN   80      82       78       95       80
# 57    58   Growlithe   Fire       NaN   55      70       45       70       50
# 58    59    Arcanine   Fire       NaN   90     110       80      100       80
# 59    60     Poliwag  Water       NaN   40      50       40       40       40
# 60    61   Poliwhirl  Water       NaN   65      65       65       50       50
# 61    62   Poliwrath  Water  Fighting   90      95       95       70       90
# 68    69  Bellsprout  Grass    Poison   50      75       35       70       30
# 69    70  Weepinbell  Grass    Poison   65      90       50       85       45
# 70    71  Victreebel  Grass    Poison   80     105       65      100       70
# 71    72   Tentacool  Water    Poison   40      40       35       50      100
# 72    73  Tentacruel  Water    Poison   80      70       65       80      120
# 76    77      Ponyta   Fire       NaN   50      85       55       65       65
# 77    78    Rapidash   Fire       NaN   65     100       70       80       80
# 78    79    Slowpoke  Water   Psychic   90      65       65       40       40
# 79    80     Slowbro  Water   Psychic   95      75      110      100       80
# 85    86        Seel  Water       NaN   65      45       55       45       70
# 86    87     Dewgong  Water       Ice   90      70       80       70       95
# 89    90    Shellder  Water       NaN   30      65      100       45       25
# 90    91    Cloyster  Water       Ice   50      95      180       85       45
# 97    98      Krabby  Water       NaN   30     105       90       25       25
# 98    99     Kingler  Water       NaN   55     130      115       50       50
# 101  102   Exeggcute  Grass   Psychic   60      40       80       60       45
# 102  103   Exeggutor  Grass   Psychic   95      95       85      125       65
# 113  114     Tangela  Grass       NaN   65      55      115      100       40
# 115  116      Horsea  Water       NaN   30      40       70       70       25
# 116  117      Seadra  Water       NaN   55      65       95       95       45
# 117  118     Goldeen  Water       NaN   45      67       60       35       50
# 118  119     Seaking  Water       NaN   80      92       65       65       80
# 119  120      Staryu  Water       NaN   30      45       55       70       55
# 120  121     Starmie  Water   Psychic   60      75       85      100       85
# 125  126      Magmar   Fire       NaN   65      95       57      100       85
# 128  129    Magikarp  Water       NaN   20      10       55       15       20
# 129  130    Gyarados  Water    Flying   95     125       79       60      100
# 130  131      Lapras  Water       Ice  130      85       80       85       95
# 133  134    Vaporeon  Water       NaN  130      65       60      110       95
# 135  136     Flareon   Fire       NaN   65     130       60       95      110
# 145  146     Moltres   Fire    Flying   90     100       90      125       85
#
#      Speed
# 0       45
# 1       60
# 2       80
# 3       65
# 4       80
# 5      100
# 6       43
# 7       58
# 8       78
# 36      65
# 37     100
# 42      30
# 43      40
# 44      50
# 53      55
# 54      85
# 57      60
# 58      95
# 59      90
# 60      90
# 61      70
# 68      40
# 69      55
# 70      70
# 71      70
# 72     100
# 76      90
# 77     105
# 78      15
# 79      30
# 85      45
# 86      70
# 89      40
# 90      70
# 97      50
# 98      75
# 101     40
# 102     55
# 113     60
# 115     60
# 116     85
# 117     63
# 118     68
# 119     85
# 120    115
# 125     93
# 128     80
# 129     81
# 130     60
# 133     65
# 135     65
# 145     90

# %%
# 13. Usa un estilo 'whitegrid'

# %%
# estilo 'whitegrid'

sns.set_style('whitegrid')

plt.figure(figsize=(12,6))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

# %%
sns.set_style('whitegrid')

# Dibujar los diagramas de violín
plt.figure(figsize = (13,6))
sns.violinplot(data = df)


plt.show()

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colors = ['#78C850', '#F08030', '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(x = 'Type 1', y = 'Attack', data = df, palette = colors)
plt.show()
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_12660\1911039135.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Type 1', y='Attack', data = df, palette = colors)

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
# Estilo visual
sns.set_style('whitegrid')

# Lista de colores para los tres tipos
colors = ['#78C850', '#F08030', '#6890F0']

# Crear el swarmplot
plt.figure(figsize = (8,6))
sns.swarmplot(x = 'Type 1', y='Attack', data=df, palette=colors)

plt.show()
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_12660\4057278306.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Type 1', y='Attack', data=df, palette=colors)

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# Pon un título con pyplot (como siempre)

# %%
# Estilo visual
sns.set_style('whitegrid')

# Colores personalizados
colors = ['#78C850', '#F08030', '#6890F0']

# Diagrama de violín (sin cajas internas)
plt.figure(figsize = (15,6))
sns.violinplot(x = 'Type 1', y = 'Attack', data = df, palette = colors, inner = None)

# Swarmplot con transparencia
sns.swarmplot(x = 'Type 1', y = 'Attack', data = df, color = 'k', alpha = 0.9)

# Título del gráfico
plt.title("Clasificación de Pokémon según el Ataque (Grass, Fire, Water)")


plt.show()
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_12660\2573236899.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Type 1', y = 'Attack', data = df, palette = colors, inner = None)
# C:\Users\mikel\AppData\Local\Temp\ipykernel_12660\2573236899.py:9: UserWarning:
# The palette list has fewer values (3) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(x = 'Type 1', y = 'Attack', data = df, palette = colors, inner = None)

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

# %%
# Recordar el DataFrame filtrado
df_grass_fire_water = df[df['Type 1'].isin(['Grass', 'Fire', 'Water'])]


df_grass_fire_water.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
# Aplicar melt() 
df_gfw = df_grass_fire_water.melt(
    id_vars = ['Name', 'Type 1'],                     #
    value_vars = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'],  
    var_name = 'New Column',                         
    value_name = 'Value')                              


df_gfw.head()
# Out:
#          Name Type 1 New Column  Value
# 0   Bulbasaur  Grass         HP     45
# 1     Ivysaur  Grass         HP     60
# 2    Venusaur  Grass         HP     80
# 3  Charmander   Fire         HP     39
# 4  Charmeleon   Fire         HP     58

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
sns.swarmplot(df_gfw)
# Out:
# <Axes: >

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %%
# Paleta Pokémon usada antes
colors = ['#78C850', '#F08030', '#6890F0']  # Grass, Fire, Water

# Tamaño de figura con plt
plt.figure(figsize = (10, 6))

# Gráfico anterior
sns.swarmplot(df_gfw)


# Límite del eje Y entre 0 y 200
plt.ylim(0, 200)

# Leyenda en la esquina superior izquierda con bbox_to_anchor y loc=2 (upper left)
plt.legend(title = 'Type 1', bbox_to_anchor = (0, 1), loc = 2)


plt.show()
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_12660\202817144.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Type 1', bbox_to_anchor=(0, 1), loc=2)

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
# Correlaciones del DataFrame original

correlaciones = df.corr()

correlaciones
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 3
#       1 # Correlaciones del DataFrame original
# ----> 3 correlaciones = df.corr()
#       5 correlaciones
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Bulbasaur'

# %%
# ¿la correlación entre qué valores se encuentra?
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML)

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
plt.figure(figsize = (8,5))
sns.histplot(df['Defense'], kde = True, color = 'skyblue', bins = 20)


plt.title("Distribución y densidad de probabilidad del nivel de Defensa")
plt.xlabel("Defense")
plt.ylabel("Frecuencia")

plt.show()

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

# %%
# Diagrama de barras del 'Type 1' usando el DataFrame original
plt.figure(figsize = (10,6))
sns.countplot(x = 'Type 1', data=df, palette='viridis')


# Título y etiquetas
plt.title("Número de Pokémon por Tipo Primario (Type 1)")
plt.xlabel("Tipo Primario")
plt.ylabel("Cantidad")

plt.show()
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_12660\395876910.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Type 1', data=df, palette='viridis')

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

# %%
sns.catplot(
    x = 'Type 1',
    y = 'Defense',
    hue = 'Type 2',
    col =  'Legendary',
    data = df,
    kind = 'swarm',      
    height = 6,
    aspect = 1.2,
    palette = 'Set2')

plt.subplots_adjust(top=0.85)
plt.suptitle("Nivel de Defensa según Tipo Primario y Tipo Secundario\nSubplots: Legendarios vs No Legendarios")

plt.show()

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
plt.figure(figsize=(8,6))

sns.kdeplot(
    x = 'Attack',
    y = 'Defense',
    data = df,
    fill = True,          
    cmap = 'viridis',    
    thresh = 0.05,       
    levels = 10)

plt.xlabel("Ataque")
plt.ylabel("Defensa")
plt.show()

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

# %%
sns.jointplot(x='Attack',
              y='Defense',
              data=df,
              kind='kde',
              fill=True,
              cmap='viridis',
              height=7)

plt.suptitle("Distribución conjunta de Ataque y Defensa", y=1.02)
plt.show()
