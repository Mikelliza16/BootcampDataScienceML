# %% [markdown]
# # Ex - GroupBy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).
#
# ### Paso 2. Importe el conjunto de datos desde esta [dirección](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv"

df = pd.read_csv(url)

df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
df[df["continent"].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.
# ### Paso 3. Asignarlo a una variable llamada bebidas.

# %%
df_bebidas = df

# %%
df_bebidas
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?
# ### Paso 4. ¿Qué continente consume más cerveza de media?

# %%
df['beer_servings'].mean()
# Out:
# np.float64(106.16062176165804)

# %%
df.groupby('continent')

# %%
df.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
df.groupby('continent')['beer_servings'].mean().sort_values(ascending=False)
# Out:
# continent
# EU    193.777778
# SA    175.083333
# OC     89.687500
# AF     61.471698
# AS     37.045455
# Name: beer_servings, dtype: float64

# %%
df.groupby('continent')['beer_servings'].mean().idxmax()
# Out:
# 'EU'

# %%
#Deberimos sustituir los valores null-s para tener en cuenta ese continente en el momento de realizar el análisis.
df[df["continent"].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
df["continent"] = df["continent"].fillna("NCA")

# %%
df["continent"].value_counts()
# Out:
# continent
# AF     53
# EU     45
# AS     44
# NCA    23
# OC     16
# SA     12
# Name: count, dtype: int64

# %%
df.groupby('continent')['beer_servings'].mean().idxmax()
# Out:
# 'EU'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.
# ### Paso 5. Imprima las estadísticas de consumo de vino de cada continente.

# %%
df.groupby('continent')['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# NCA         23.0   24.521739  28.266378  1.0   5.0   11.0   34.00  100.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
df.groupby("continent").describe()
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# NCA                23.0  145.434783  79.621163   1.0   80.00  143.0  198.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  spirit_servings              ... wine_servings         \
#              max           count        mean  ...           75%    max
# continent                                     ...
# AF         376.0            53.0   16.339623  ...         13.00  233.0
# AS         247.0            44.0   60.840909  ...          8.00  123.0
# ...

# %%
df.groupby("continent")["wine_serving"].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.groupby("continent")["wine_serving"].describe()
#
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
# ...

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column
# ### Paso 6. Imprima el consumo medio de alcohol por continente para cada columna.

# %%
df.groupby('continent')

# %%
df.groupby('continent').mean(numeric_only=True)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# NCA           145.434783       165.739130      24.521739
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# NCA                            5.995652
# OC                             3.381250
# SA                             6.308333

# %%
df.groupby('continent')['total_litres_of_pure_alcohol'].mean()
# Out:
# continent
# AF     3.007547
# AS     2.170455
# EU     8.617778
# NCA    5.995652
# OC     3.381250
# SA     6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column
# ### Paso 7. Imprima la mediana del consumo de alcohol por continente para cada columna.

# %%
df.groupby('continent').median(numeric_only=True)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# NCA                143.0            137.0           11.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# NCA                                6.30
# OC                                 1.75
# SA                                 6.85

# %%
df.groupby('continent')['total_litres_of_pure_alcohol'].median()
# Out:
# continent
# AF      2.30
# AS      1.20
# EU     10.00
# NCA     6.30
# OC      1.75
# SA      6.85
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption per continent.
# ### Paso 8. Imprima los valores medios, mínimos y máximos del consumo de alcohol por continente.

# %%
df.groupby('continent')['spirit_servings'].aggregate(["mean", "min","max"])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# NCA        165.739130   68  438
# OC          58.437500    0  254
# SA         114.750000   25  302

# %%
df.groupby('continent')['total_litres_of_pure_alcohol'].describe()
# Out:
#            count      mean       std  min   25%    50%     75%   max
# continent
# AF          53.0  3.007547  2.647557  0.0  0.70   2.30   4.700   9.1
# AS          44.0  2.170455  2.770239  0.0  0.10   1.20   2.425  11.5
# EU          45.0  8.617778  3.358455  0.0  6.60  10.00  10.900  14.4
# NCA         23.0  5.995652  2.409353  2.2  4.30   6.30   7.000  11.9
# OC          16.0  3.381250  3.345688  0.0  1.00   1.75   6.150  10.4
# SA          12.0  6.308333  1.531166  3.8  5.25   6.85   7.375   8.3
