# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, None, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, None, 3, None, 2, None, 2, None, None, 1, 2, None],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ### Import libraries

# %% [markdown]
# ### Step 1. This is the data given as a dictionary. Create a dataframe and assign it to a variable called army.
#
# ### Paso 1. Estos son los datos proporcionados en forma de diccionario. Crea un marco de datos y asígnalo a una variable llamada army.

# %%
import pandas as pd

df_army = pd.DataFrame(raw_data)

# Mostrar el DataFrame
df_army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st   523.0        5  1045         1        1.0        1
# 1   Nighthawks     1st    52.0       42   957         5        NaN        0
# 2   Nighthawks     2nd    25.0        2  1099        62        3.0        1
# 3   Nighthawks     2nd   616.0        2  1400        26        NaN        1
# 4     Dragoons     1st    43.0        4  1592        73        2.0        0
# 5     Dragoons     1st   234.0        7  1006        37        NaN        1
# 6     Dragoons     2nd   523.0        8   987       949        2.0        0
# 7     Dragoons     2nd    62.0        3   849        48        NaN        1
# 8       Scouts     1st     NaN        4   973        48        NaN        0
# 9       Scouts     1st    73.0        7  1005       435        1.0        0
# 10      Scouts     2nd    37.0        8  1099        63        2.0        1
# ...

# %% [markdown]
# ### Step 2. Check missing values
# ### Paso 2. Comprueba los valores que faltan.

# %%
df_army.info
# Out:
# <bound method DataFrame.info of       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st   523.0        5  1045         1        1.0        1
# 1   Nighthawks     1st    52.0       42   957         5        NaN        0
# 2   Nighthawks     2nd    25.0        2  1099        62        3.0        1
# 3   Nighthawks     2nd   616.0        2  1400        26        NaN        1
# 4     Dragoons     1st    43.0        4  1592        73        2.0        0
# 5     Dragoons     1st   234.0        7  1006        37        NaN        1
# 6     Dragoons     2nd   523.0        8   987       949        2.0        0
# 7     Dragoons     2nd    62.0        3   849        48        NaN        1
# 8       Scouts     1st     NaN        4   973        48        NaN        0
# 9       Scouts     1st    73.0        7  1005       435        1.0        0
# 10      Scouts     2nd    37.0        8  1099        63        2.0        1
# ...

# %%
df_army.isnull()
# Out:
#     regiment  company  deaths  battles   size  veterans  readiness  armored  \
# 0      False    False   False    False  False     False      False    False
# 1      False    False   False    False  False     False       True    False
# 2      False    False   False    False  False     False      False    False
# 3      False    False   False    False  False     False       True    False
# 4      False    False   False    False  False     False      False    False
# 5      False    False   False    False  False     False       True    False
# 6      False    False   False    False  False     False      False    False
# 7      False    False   False    False  False     False       True    False
# 8      False    False    True    False  False     False       True    False
# 9      False    False   False    False  False     False      False    False
# 10     False    False   False    False  False     False      False    False
# ...

# %%
df_army.isnull().sum()
# Out:
# regiment     0
# company      0
# deaths       1
# battles      0
# size         0
# veterans     0
# readiness    6
# armored      0
# deserters    0
# origin       0
# dtype: int64

# %%
df_army[(df_army["deaths"].isnull()) | (df_army["readiness"].isnull()
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 1   Nighthawks     1st    52.0       42   957         5        NaN        0
# 3   Nighthawks     2nd   616.0        2  1400        26        NaN        1
# 5     Dragoons     1st   234.0        7  1006        37        NaN        1
# 7     Dragoons     2nd    62.0        3   849        48        NaN        1
# 8       Scouts     1st     NaN        4   973        48        NaN        0
# 11      Scouts     2nd    35.0        9  1523       345        NaN        1
#
#     deserters      origin
# 1          24  California
# 3           2     Florida
# 5           4        Iowa
# 7          31  Washington
# 8           2      Oregon
# 11          3     Georgia

# %%
df_army.isnull().any()
# Out:
# regiment     False
# company      False
# deaths        True
# battles      False
# size         False
# veterans     False
# readiness     True
# armored      False
# deserters    False
# origin       False
# dtype: bool

# %% [markdown]
# ###Step 3. Drop features, if there are more than 30% missing values.
# ###Paso 3. Eliminar características si hay más del 30 % de valores perdidos.

# %%
df_army.dropna(thresh= len(df_army) * 0.7, inplace= True)

# %%
df_army
# Out:
# Empty DataFrame
# Columns: [regiment, company, deaths, battles, size, veterans, readiness, armored, deserters, origin]
# Index: []

# %%
len(df_army) * 0.7
# Out:
# 8.399999999999999

# %%
# Calcular el porcentaje de valores faltantes por columna
valores_perdidos = df_army.isnull().mean() * 100

# Eliminar columnas con más del 30% de valores faltantes
df_army.drop(columns = valores_perdidos[valores_perdidos > 30].index)

# Mostrar las columnas restantes
print("Columnas restantes en el DataFrame:")
print(df_army.columns)
# Out:
# Columnas restantes en el DataFrame:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'armored', 'deserters', 'origin'],
#       dtype='object')

# %% [markdown]
# ### Step 4. Fill missing values with the mean of their regiment.
# ### Paso 4. Rellene los valores que faltan con la media de su regimiento.

# %%
df_army.info
# Out:
# <bound method DataFrame.info of       regiment company  deaths  battles  size  veterans  armored  deserters  \
# 0   Nighthawks     1st   523.0        5  1045         1        1          4
# 1   Nighthawks     1st    52.0       42   957         5        0         24
# 2   Nighthawks     2nd    25.0        2  1099        62        1         31
# 3   Nighthawks     2nd   616.0        2  1400        26        1          2
# 4     Dragoons     1st    43.0        4  1592        73        0          3
# 5     Dragoons     1st   234.0        7  1006        37        1          4
# 6     Dragoons     2nd   523.0        8   987       949        0         24
# 7     Dragoons     2nd    62.0        3   849        48        1         31
# 8       Scouts     1st     NaN        4   973        48        0          2
# 9       Scouts     1st    73.0        7  1005       435        0          3
# 10      Scouts     2nd    37.0        8  1099        63        1          2
# ...

# %%
df_army["deaths"].mean()
# Out:
# Series([], Name: deaths, dtype: float64)

# %%
df_army["deaths"].fillna(df_army["deaths"].mean())
# Out:
# Series([], Name: deaths, dtype: float64)

# %%
round(df_army.groupby("regiment")["deaths"].mean())
# Out:
# Series([], Name: deaths, dtype: float64)

# %%
round(df_army.groupby("regiment")["deaths"].mean()["scouts"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scouts'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ...

# %%
round(df_army.groupby("regiment")["deaths"].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# ### Step 5. Set the 'origin' colum as the index of the dataframe
# ### Paso 5. Establezca la columna «origin» como índice del marco de datos.

# %%
df_army.set_index("origin")
# Out:
#               regiment company  deaths  battles  size  veterans  armored  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1
# California  Nighthawks     1st    52.0       42   957         5        0
# Texas       Nighthawks     2nd    25.0        2  1099        62        1
# Florida     Nighthawks     2nd   616.0        2  1400        26        1
# Maine         Dragoons     1st    43.0        4  1592        73        0
# Iowa          Dragoons     1st   234.0        7  1006        37        1
# Alaska        Dragoons     2nd   523.0        8   987       949        0
# Washington    Dragoons     2nd    62.0        3   849        48        1
# Oregon          Scouts     1st     NaN        4   973        48        0
# Wyoming         Scouts     1st    73.0        7  1005       435        0
# Louisana        Scouts     2nd    37.0        8  1099        63        1
# Georgia         Scouts     2nd    35.0        9  1523       345        1
#
# ...

# %% [markdown]
# ### Step 6. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska
# ### Paso 6. Seleccione las columnas «muertes», «tamaño» y «desertores» de Maine y Alaska.

# %%
df_army = df_army.set_index('origin')

# %%
df_army.loc[['Maine','Alaska']][['deaths', 'size', 'deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine     43.0  1592          3
# Alaska   523.0   987         24

# %% [markdown]
# ### Step 7. Select the rows 3 to 7 and the columns 3 to 6
# ### Paso 7. Seleccione las filas 3 a 7 y las columnas 3 a 6.

# %%
df_army.iloc[2:8, 2:7]
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Texas         25.0        2  1099        62        3.0
# Florida      616.0        2  1400        26        NaN
# Maine         43.0        4  1592        73        2.0
# Iowa         234.0        7  1006        37        NaN
# Alaska       523.0        8   987       949        2.0
# Washington    62.0        3   849        48        NaN

# %% [markdown]
# ### Step 8. Select every row after the fourth row and all columns
# ### Paso 8. Selecciona todas las filas después de la cuarta fila y todas las columnas.

# %%
df_army.iloc[4:,:]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st    43.0        4  1592        73        2.0
# Iowa        Dragoons     1st   234.0        7  1006        37        NaN
# Alaska      Dragoons     2nd   523.0        8   987       949        2.0
# Washington  Dragoons     2nd    62.0        3   849        48        NaN
# Oregon        Scouts     1st     NaN        4   973        48        NaN
# Wyoming       Scouts     1st    73.0        7  1005       435        1.0
# Louisana      Scouts     2nd    37.0        8  1099        63        2.0
# Georgia       Scouts     2nd    35.0        9  1523       345        NaN
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 9. Select every row up to the 4th row and all columns
# ### Paso 9. Selecciona todas las filas hasta la cuarta fila y todas las columnas.

# %%
df_army.iloc[:4,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1.0
# California  Nighthawks     1st    52.0       42   957         5        NaN
# Texas       Nighthawks     2nd    25.0        2  1099        62        3.0
# Florida     Nighthawks     2nd   616.0        2  1400        26        NaN
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %%
df_army.iloc[:4,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1.0
# California  Nighthawks     1st    52.0       42   957         5        NaN
# Texas       Nighthawks     2nd    25.0        2  1099        62        3.0
# Florida     Nighthawks     2nd   616.0        2  1400        26        NaN
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %% [markdown]
# ### Step 10. Select the 3rd column up to the 7th column
# ### Paso 10. Seleccione la tercera columna hasta la séptima columna.

# %%
df_army.iloc[:,3:7]
# Out:
#             battles  size  veterans  readiness
# origin
# Arizona           5  1045         1        1.0
# California       42   957         5        NaN
# Texas             2  1099        62        3.0
# Florida           2  1400        26        NaN
# Maine             4  1592        73        2.0
# Iowa              7  1006        37        NaN
# Alaska            8   987       949        2.0
# Washington        3   849        48        NaN
# Oregon            4   973        48        NaN
# Wyoming           7  1005       435        1.0
# Louisana          8  1099        63        2.0
# Georgia           9  1523       345        NaN

# %% [markdown]
# ### Step 11. Select rows where df.deaths is greater than 50
# ### Paso 11. Selecciona las filas en las que df.deaths sea mayor que 50.

# %%
df_army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1.0
# California  Nighthawks     1st    52.0       42   957         5        NaN
# Texas       Nighthawks     2nd    25.0        2  1099        62        3.0
# Florida     Nighthawks     2nd   616.0        2  1400        26        NaN
# Maine         Dragoons     1st    43.0        4  1592        73        2.0
# Iowa          Dragoons     1st   234.0        7  1006        37        NaN
# Alaska        Dragoons     2nd   523.0        8   987       949        2.0
# Washington    Dragoons     2nd    62.0        3   849        48        NaN
# Oregon          Scouts     1st     NaN        4   973        48        NaN
# Wyoming         Scouts     1st    73.0        7  1005       435        1.0
# Louisana        Scouts     2nd    37.0        8  1099        63        2.0
# ...

# %%
mascara = df_army[df_army['deaths'] > 50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1.0
# California  Nighthawks     1st    52.0       42   957         5        NaN
# Florida     Nighthawks     2nd   616.0        2  1400        26        NaN
# Iowa          Dragoons     1st   234.0        7  1006        37        NaN
# Alaska        Dragoons     2nd   523.0        8   987       949        2.0
# Washington    Dragoons     2nd    62.0        3   849        48        NaN
# Wyoming         Scouts     1st    73.0        7  1005       435        1.0
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Wyoming           0          3

# %%
df_army[mascara]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11308\2899035551.py in ?()
# ----> 1 df_army[mascara]
#
# c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4096             return self._getitem_slice(key)
#    4097
#    4098         # Do we have a (boolean) DataFrame?
#    4099         if isinstance(key, DataFrame):
# -> 4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
#
# c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   11044                         stacklevel=2,
#   11045                     )
#   11046
#   11047         other = common.apply_if_callable(other, self)
# ...

# %% [markdown]
# ### Step 12. Select rows where df.deaths is greater than 500 or less than 50
# ### Paso 12. Selecciona las filas en las que df.deaths sea mayor que 500 o menor que 50.

# %%
(df_army['deaths'] > 500) | (df_army['deaths'] < 50)
# Out:
# origin
# Arizona        True
# California    False
# Texas          True
# Florida        True
# Maine          True
# Iowa          False
# Alaska         True
# Washington    False
# Oregon        False
# Wyoming       False
# Louisana       True
# Georgia        True
# Name: deaths, dtype: bool

# %%
df_army[(df_army['deaths'] > 500) | (df_army['deaths'] < 50)]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st   523.0        5  1045         1        1.0
# Texas     Nighthawks     2nd    25.0        2  1099        62        3.0
# Florida   Nighthawks     2nd   616.0        2  1400        26        NaN
# Maine       Dragoons     1st    43.0        4  1592        73        2.0
# Alaska      Dragoons     2nd   523.0        8   987       949        2.0
# Louisana      Scouts     2nd    37.0        8  1099        63        2.0
# Georgia       Scouts     2nd    35.0        9  1523       345        NaN
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %% [markdown]
# ### Step 13. Select all the regiments not named "Dragoons"
# ### Paso 13. Selecciona todos los regimientos que no se llamen «Dragones».

# %%
df_army[df_army["regiment"] != "Dragoons"]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st   523.0        5  1045         1        1.0
# California  Nighthawks     1st    52.0       42   957         5        NaN
# Texas       Nighthawks     2nd    25.0        2  1099        62        3.0
# Florida     Nighthawks     2nd   616.0        2  1400        26        NaN
# Oregon          Scouts     1st     NaN        4   973        48        NaN
# Wyoming         Scouts     1st    73.0        7  1005       435        1.0
# Louisana        Scouts     2nd    37.0        8  1099        63        2.0
# Georgia         Scouts     2nd    35.0        9  1523       345        NaN
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# ...

# %% [markdown]
# ### Step 14. Select the rows called Texas and Arizona
# ### Paso 14. Seleccione las filas llamadas Texas y Arizona.

# %%
df_army.loc[['Texas', 'Arizona']]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd    25.0        2  1099        62        3.0
# Arizona  Nighthawks     1st   523.0        5  1045         1        1.0
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %% [markdown]
# ### Step 15. Select the third cell in the row named Arizona
# ### Paso 15. Seleccione la tercera celda de la fila denominada Arizona.

# %%
df_army.loc['Arizona'][2]
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_11308\3883920954.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_army.loc['Arizona'][2]
# np.float64(523.0)

# %%
df_army.loc['Arizona'].iloc[2]
# Out:
# np.float64(523.0)

# %% [markdown]
# ### Step 16. Select the third cell down in the column named deaths
# ### Paso 16. Seleccione la tercera celda hacia abajo en la columna denominada «muertes».

# %%
df_army.loc["deaths"][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'deaths'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ...

# %%
df_army.loc["deaths"].iloc[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'deaths'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ...
