# %% [markdown]
# # Support Vector Machines - Exercise 1

# %% [markdown]
# In this exercise, we'll be using support vector machines (SVMs) to build a spam classifier.  We'll start with SVMs on some simple 2D data sets to see how they work.  Then we'll do some pre-processing work on a set of raw emails and build a classifier on the processed emails using a SVM to determine if they are spam or not.

# %% [markdown]
# The first thing we're going to do is look at a simple 2-dimensional data set and see how a linear SVM works on the data set for varying values of C (similar to the regularization term in linear/logistic regression).  Let's load the data.
# ## Exercise 1
# #### 1. Load libraries

# %%
import numpy as np
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt

#Modelos
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV

#Metricas
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# #### 2. Load data
# Load the file *ejer_1_data1.mat*. Find the way for loading this kind of file. **scipy.io.loadmat**

# %%
loadmat = scipy.io.loadmat('ejer_1_data1.mat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ejer_1_data1.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 loadmat = scipy.io.loadmat('ejer_1_data1.mat')
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:233, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)    230     3.14159265+3.14159265j])
#     231 """
#     232 variable_names = kwargs.pop('variable_names', None)
# --> 233 with _open_file_context(file_name, appendmat) as f:
#     234     MR, _ = mat_reader_factory(f, **kwargs)
#     235     matfile_dict = MR.get_variables(variable_names)
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ejer_1_data1.mat'

# %%
print(loadmat.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(loadmat.keys())
#
# NameError: name 'loadmat' is not defined

# %% [markdown]
# #### 3. Create a DataFrame with the features and target

# %%
X = loadmat['X']  
y = loadmat['y']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 X = loadmat['X']
#       2 y = loadmat['y']
#
# NameError: name 'loadmat' is not defined

# %%
data = pd.DataFrame(X, columns=['feature1', 'feature2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = pd.DataFrame(X, columns=['feature1', 'feature2'])
#
# NameError: name 'X' is not defined

# %%
data['target'] = y.ravel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data['target'] = y.ravel()
#
# NameError: name 'y' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### 4. Plot a scatterplot with the data

# %%
plt.figure(figsize=(8,6))

clase1 = data[data['target'] == 1]
plt.scatter(clase1['feature1'], clase1['feature2'], 
            c='red', marker='^', s=60, label='Clase 1')

clase0 = data[data['target'] == 0]
plt.scatter(clase0['feature1'], clase0['feature2'], 
            c='blue', marker='o', s=60, label='Clase 0')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatterplot 2D - Datos para SVM Lineal')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 plt.figure(figsize=(8,6))
# ----> 3 clase1 = data[data['target'] == 1]
#       4 plt.scatter(clase1['feature1'], clase1['feature2'],
#       5             c='red', marker='^', s=60, label='Clase 1')
#       7 clase0 = data[data['target'] == 0]
#
# NameError: name 'data' is not defined

# %% [markdown]
# Notice that there is one outlier positive example that sits apart from the others.  The classes are still linearly separable but it's a very tight fit.  We're going to train a linear support vector machine to learn the class boundary.
#
# #### 5. LinearSVC
# Declare a Linear SVC with the hyperparamenters:
#
# ```Python
# LinearSVC(C=1, loss='hinge', max_iter=10000)
# ```

# %%
model = LinearSVC(C=1, loss='hinge', max_iter=10000)
model.fit(data[['feature1', 'feature2']], data['target'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 model = LinearSVC(C=1, loss='hinge', max_iter=10000)
# ----> 2 model.fit(data[['feature1', 'feature2']], data['target'])
#
# NameError: name 'data' is not defined

# %%
print("Coeficientes (w):", model.coef_)
print("Intercepto (b):", model.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print("Coeficientes (w):", model.coef_)
#       2 print("Intercepto (b):", model.intercept_)
#
# AttributeError: 'LinearSVC' object has no attribute 'coef_'

# %% [markdown]
# #### 6. Try the performance (score)
# For the first experiment we'll use C=1 and see how it performs.

# %%
train_score = model.score(data[['feature1', 'feature2']], data['target'])
print(f"Accuracy con C=1: {train_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_score = model.score(data[['feature1', 'feature2']], data['target'])
#       2 print(f"Accuracy con C=1: {train_score:.4f}")
#
# NameError: name 'data' is not defined

# %%
y_pred = model.predict(data[['feature1', 'feature2']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 y_pred = model.predict(data[['feature1', 'feature2']])
#
# NameError: name 'data' is not defined

# %%
print("\nReporte de clasificación:")
print(classification_report(data['target'], y_pred))
# Out:
# Reporte de clasificación:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 print("\nReporte de clasificación:")
# ----> 2 print(classification_report(data['target'], y_pred))
#
# NameError: name 'data' is not defined

# %% [markdown]
# It appears that it mis-classified the outlier.
#
# #### 7. Increase the value of C until you get a perfect classifier

# %%
C_values = [1, 10, 100, 1000, 10000]
results = []

# %%
for C in C_values:
    model = LinearSVC(C=C, loss='hinge', max_iter=10000, random_state=42)
    model.fit(data[['feature1', 'feature2']], data['target'])
    
    score = model.score(data[['feature1', 'feature2']], data['target'])
    results.append(score)
    
    print(f"C={C}: Accuracy = {score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 for C in C_values:
#       2     model = LinearSVC(C=C, loss='hinge', max_iter=10000, random_state=42)
# ----> 3     model.fit(data[['feature1', 'feature2']], data['target'])
#       5     score = model.score(data[['feature1', 'feature2']], data['target'])
#       6     results.append(score)
#
# NameError: name 'data' is not defined

# %% [markdown]
# This time we got a perfect classification of the training data, however by increasing the value of C we've created a decision boundary that is no longer a natural fit for the data.  We can visualize this by looking at the confidence level for each class prediction, which is a function of the point's distance from the hyperplane.
#
# #### 8. Plot Decission Function
# Get the `decision_function()` output for the first model. Plot a scatterplot with X1, X2 and a range of colors based on `decision_function()`

# %%
model_C1 = LinearSVC(C=1, loss='hinge', max_iter=10000, random_state=42)
model_C1.fit(data[['feature1', 'feature2']], data['target'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 model_C1 = LinearSVC(C=1, loss='hinge', max_iter=10000, random_state=42)
# ----> 2 model_C1.fit(data[['feature1', 'feature2']], data['target'])
#
# NameError: name 'data' is not defined

# %%
decision_values = model_C1.decision_function(data[['feature1', 'feature2']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 decision_values = model_C1.decision_function(data[['feature1', 'feature2']])
#
# NameError: name 'data' is not defined

# %%
plt.figure(figsize=(10,6))

scatter = plt.scatter(data['feature1'], data['feature2'], 
                     c=decision_values, 
                     cmap='RdBu_r', 
                     s=60, 
                     edgecolors='black', 
                     linewidth=0.5)

plt.colorbar(scatter, label='Decision Function (distancia al hiperplano)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Function - Modelo C=1 (muestra el outlier problemático)')

# - marcar hiperplano (decision=0)
plt.contour(data[['feature1', 'feature2']], model_C1.decision_function, 
            levels=[0], colors='black', linestyles='-', linewidth=2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 plt.figure(figsize=(10,6))
# ----> 3 scatter = plt.scatter(data['feature1'], data['feature2'],
#       4                      c=decision_values,
#       5                      cmap='RdBu_r',
#       6                      s=60,
#       7                      edgecolors='black',
#       8                      linewidth=0.5)
#      10 plt.colorbar(scatter, label='Decision Function (distancia al hiperplano)')
#      11 plt.xlabel('Feature 1')
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### 9. Do the same with the second model

# %% [markdown]
# https://www.svm-tutorial.com/2015/06/svm-understanding-math-part-3/

# %%
model_highC = LinearSVC(C=1000, loss='hinge', max_iter=10000, random_state=42)
model_highC.fit(data[['feature1', 'feature2']], data['target'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 model_highC = LinearSVC(C=1000, loss='hinge', max_iter=10000, random_state=42)
# ----> 2 model_highC.fit(data[['feature1', 'feature2']], data['target'])
#
# NameError: name 'data' is not defined

# %%
decision_values_highC = model_highC.decision_function(data[['feature1', 'feature2']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 decision_values_highC = model_highC.decision_function(data[['feature1', 'feature2']])
#
# NameError: name 'data' is not defined

# %%
plt.figure(figsize=(10,6))

scatter = plt.scatter(data['feature1'], data['feature2'], 
                      c=decision_values_highC, 
                      cmap='RdBu_r', 
                      s=60, 
                      edgecolors='black', 
                      linewidth=0.5)

plt.colorbar(scatter, label='Decision Function (distance from hyperplane)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Function - Modelo con C=1000 (perfect classification)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 plt.figure(figsize=(10,6))
# ----> 3 scatter = plt.scatter(data['feature1'], data['feature2'],
#       4                       c=decision_values_highC,
#       5                       cmap='RdBu_r',
#       6                       s=60,
#       7                       edgecolors='black',
#       8                       linewidth=0.5)
#      10 plt.colorbar(scatter, label='Decision Function (distance from hyperplane)')
#      11 plt.xlabel('Feature 1')
#
# NameError: name 'data' is not defined

# %%
x_min, x_max = data['feature1'].min() - 1, data['feature1'].max() + 1
y_min, y_max = data['feature2'].min() - 1, data['feature2'].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 500),
                     np.linspace(y_min, y_max, 500))

Z = model_highC.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, levels=[0], colors='black', linestyles='-', linewidths=2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 x_min, x_max = data['feature1'].min() - 1, data['feature1'].max() + 1
#       2 y_min, y_max = data['feature2'].min() - 1, data['feature2'].max() + 1
#       3 xx, yy = np.meshgrid(np.linspace(x_min, x_max, 500),
#       4                      np.linspace(y_min, y_max, 500))
#
# NameError: name 'data' is not defined

# %% [markdown]
# Now we're going to move from a linear SVM to one that's capable of non-linear classification using kernels.  We're first tasked with implementing a gaussian kernel function.  Although scikit-learn has a gaussian kernel built in, for transparency we'll implement one from scratch.
#
# ## Exercise 2

# %% [markdown]
# That result matches the expected value from the exercise.  Next we're going to examine another data set, this time with a non-linear decision boundary.

# %% [markdown]
# #### 1. Load the data `ejer_1_data2.mat`

# %%
loadmat = scipy.io.loadmat('data/ejer_1_data2.mat')
print(loadmat.keys())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ejer_1_data2.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 loadmat = scipy.io.loadmat('data/ejer_1_data2.mat')
#       2 print(loadmat.keys())
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:233, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)    230     3.14159265+3.14159265j])
#     231 """
#     232 variable_names = kwargs.pop('variable_names', None)
# --> 233 with _open_file_context(file_name, appendmat) as f:
#     234     MR, _ = mat_reader_factory(f, **kwargs)
#     235     matfile_dict = MR.get_variables(variable_names)
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ejer_1_data2.mat'

# %% [markdown]
# #### 2. Create a DataFrame with the features and target

# %%
X = loadmat['X']  
y = loadmat['y']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 X = loadmat['X']
#       2 y = loadmat['y']
#
# NameError: name 'loadmat' is not defined

# %%
data = pd.DataFrame(X, columns=['feature1', 'feature2'])
data['target'] = y.ravel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data = pd.DataFrame(X, columns=['feature1', 'feature2'])
#       2 data['target'] = y.ravel()
#
# NameError: name 'X' is not defined

# %% [markdown]
# #### 3. Plot a scatterplot with the data

# %% [markdown]
# For this data set we'll build a support vector machine classifier using the built-in RBF kernel and examine its accuracy on the training data.  To visualize the decision boundary, this time we'll shade the points based on the predicted probability that the instance has a negative class label.  We'll see from the result that it gets most of them right.

# %%
plt.figure(figsize=(8,6))

clase1 = data[data['target'] == 1]
plt.scatter(clase1['feature1'], clase1['feature2'], 
            c='red', marker='^', s=60, label='Clase 1')

clase0 = data[data['target'] == 0]
plt.scatter(clase0['feature1'], clase0['feature2'], 
            c='blue', marker='o', s=60, label='Clase 0')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatterplot 2D - Datos para SVM Lineal')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 plt.figure(figsize=(8,6))
# ----> 3 clase1 = data[data['target'] == 1]
#       4 plt.scatter(clase1['feature1'], clase1['feature2'],
#       5             c='red', marker='^', s=60, label='Clase 1')
#       7 clase0 = data[data['target'] == 0]
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### 4. Declare a SVC with this hyperparameters
# ```Python
# SVC(C=100, gamma=10, probability=True)
# ```

# %%
model = SVC(C=100, gamma=10, probability=True, random_state=42)

# %% [markdown]
# #### 5. Fit the classifier and get the score

# %%
model.fit(data[['feature1', 'feature2']], data['target'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model.fit(data[['feature1', 'feature2']], data['target'])
#
# NameError: name 'data' is not defined

# %%
train_score = model.score(data[['feature1', 'feature2']], data['target'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 train_score = model.score(data[['feature1', 'feature2']], data['target'])
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### 6. Plot the scatter plot and probability of predicting 0 with a [sequential color](https://matplotlib.org/3.1.1/tutorials/colors/colormaps.html)

# %%
prob_class0 = model.predict_proba(data[['feature1', 'feature2']])[:, 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 prob_class0 = model.predict_proba(data[['feature1', 'feature2']])[:, 0]
#
# NameError: name 'data' is not defined

# %%
plt.figure(figsize=(10,6))

scatter = plt.scatter(data['feature1'], data['feature2'], 
                     c=prob_class0, 
                     cmap='YlOrRd',  # - colormap secuencial
                     s=60, 
                     edgecolors='black', 
                     linewidth=0.5)

plt.colorbar(scatter, label='P(Clase 0)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Probabilidad de predecir Clase 0 (SVC C=100, gamma=10)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 plt.figure(figsize=(10,6))
# ----> 3 scatter = plt.scatter(data['feature1'], data['feature2'],
#       4                      c=prob_class0,
#       5                      cmap='YlOrRd',  # - colormap secuencial
#       6                      s=60,
#       7                      edgecolors='black',
#       8                      linewidth=0.5)
#      10 plt.colorbar(scatter, label='P(Clase 0)')
#      11 plt.xlabel('Feature 1')
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### Grid search

# %%
param_grid = {'C': [0.1, 1, 10, 100, 1000], 'gamma': [0.001, 0.01, 0.1, 1, 10], 'kernel': ['rbf']}

# %%
svc = SVC(probability=True)

# %%
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5, verbose=2, n_jobs=-1)

# %%
grid_search.fit(data[['feature1', 'feature2']], data['target'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 grid_search.fit(data[['feature1', 'feature2']], data['target'])
#
# NameError: name 'data' is not defined

# %%
print("Mejores hiperparámetros:", grid_search.best_params_)
print("Mejor score:", grid_search.best_score_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print("Mejores hiperparámetros:", grid_search.best_params_)
#       2 print("Mejor score:", grid_search.best_score_)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'
