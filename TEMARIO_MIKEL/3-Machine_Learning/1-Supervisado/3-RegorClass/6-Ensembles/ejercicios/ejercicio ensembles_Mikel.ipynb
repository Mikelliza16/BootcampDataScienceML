# %% [markdown]
# # Ejercicios ensembling
# En este ejercicio vas a realizar prediciones sobre un dataset de ciudadanos indios diabéticos. Se trata de un problema de clasificación en el que intentaremos predecir 1 (diabético) 0 (no diabético).

# %% [markdown]
# ### 1. Carga las librerias que consideres comunes al notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

# %% [markdown]
# ### 2. Lee los datos de [esta direccion](https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv)
# Los nombres de columnas son:
# ```Python
# names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
# ```

# %%
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

# Cargar con nombres de columnas
df = pd.read_csv(url, names=names)

# %% [markdown]
# ### 3. Bagging
# Para este apartado tendrás que crear un ensemble utilizando la técnica de bagging ([BaggingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingClassifier.html)), mediante la cual combinarás 100 [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html). Recuerda utilizar también [cross validation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) con 10 kfolds.
#
# **Para este apartado y siguientes, no hace falta que dividas en train/test**, por hacerlo más sencillo. Simplemente divide tus datos en features y target.
#
# Establece una semilla

# %%
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url, names=names)

# %%
X = df.drop("class", axis = 1)
y = df["class"]

# BaggingClassifier con 100 árboles

base_tree = DecisionTreeClassifier(random_state=11)

bagging_model = BaggingClassifier(base_estimator = base_tree, n_estimators=100, random_state = seed)

# Validación cruzada con 10 folds
kfold = KFold(n_splits=10, shuffle=True, random_state = 11)
results = cross_val_score(bagging_model, X, y, cv = kfold, scoring = "accuracy")

print("Accuracy promedio:", results.mean())
print("Desviación estándar:", results.std())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       4 # BaggingClassifier con 100 árboles
#       6 base_tree = DecisionTreeClassifier(random_state=11)
# ----> 8 bagging_model = BaggingClassifier(base_estimator = base_tree, n_estimators=100, random_state = seed)
#      10 # Validación cruzada con 10 folds
#      11 kfold = KFold(n_splits=10, shuffle=True, random_state = 11)
#
# NameError: name 'seed' is not defined

# %% [markdown]
# ### 4. Random Forest
# En este caso entrena un [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html) con 100 árboles y un `max_features` de 3. También con validación cruzada

# %%
# max_features=3 indica que en cada nodo se evalúan 3 columnas aleatorias
model_rf = RandomForestClassifier(n_estimators = 100, max_features = 3, random_state = 11)

results_rf = cross_val_score(model_rf, X, y, cv = kfold)
print(f"Random Forest Accuracy: {results_rf.mean():.4f} ({results_rf.std():.4f})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 # max_features=3 indica que en cada nodo se evalúan 3 columnas aleatorias
#       2 model_rf = RandomForestClassifier(n_estimators = 100, max_features = 3, random_state = 11)
# ----> 4 results_rf = cross_val_score(model_rf, X, y, cv = kfold)
#       5 print(f"Random Forest Accuracy: {results_rf.mean():.4f} ({results_rf.std():.4f})")
#
# NameError: name 'kfold' is not defined

# %% [markdown]
# ### 5. AdaBoost
# Implementa un [AdaBoostClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html) con 30 árboles.

# %%
# AdaBoost suele funcionar bien con árboles muy simples (stumps), que es el default
model_ada = AdaBoostClassifier(n_estimators=30, random_state=11)

results_ada = cross_val_score(model_ada, X, y, cv=kfold)
print(f"AdaBoost Accuracy: {results_ada.mean():.4f} ({results_ada.std():.4f})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 # AdaBoost suele funcionar bien con árboles muy simples (stumps), que es el default
#       2 model_ada = AdaBoostClassifier(n_estimators=30, random_state=11)
# ----> 4 results_ada = cross_val_score(model_ada, X, y, cv=kfold)
#       5 print(f"AdaBoost Accuracy: {results_ada.mean():.4f} ({results_ada.std():.4f})")
#
# NameError: name 'kfold' is not defined

# %% [markdown]
# ### 6. GradientBoosting
# Implementa un [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html) con 100 estimadores

# %%
model_gb = GradientBoostingClassifier(n_estimators=100, random_state=seed)

results_gb = cross_val_score(model_gb, X, y, cv=kfold)
print(f"Gradient Boosting Accuracy: {results_gb.mean():.4f} ({results_gb.std():.4f})")
# Out:
# Gradient Boosting Accuracy: 0.7655 (0.0553)

# %% [markdown]
# ### 7. XGBoost
# Para este apartado utiliza un [XGBoostClassifier](https://docs.getml.com/latest/api/getml.predictors.XGBoostClassifier.html) con 100 estimadores. XGBoost no forma parte de la suite de modelos de sklearn, por lo que tendrás que instalarlo con pip install

# %%
# XGBoost requiere que las clases sean numéricas (ya lo son: 0 y 1)
# eval_metric='logloss' elimina warnings en versiones recientes
model_xgb = XGBClassifier(n_estimators=100, eval_metric='logloss', use_label_encoder=False, random_state=seed)

results_xgb = cross_val_score(model_xgb, X, y, cv=kfold)
print(f"XGBoost Accuracy: {results_xgb.mean():.4f} ({results_xgb.std():.4f})")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 # XGBoost requiere que las clases sean numéricas (ya lo son: 0 y 1)
#       2 # eval_metric='logloss' elimina warnings en versiones recientes
# ----> 3 model_xgb = XGBClassifier(n_estimators=100, eval_metric='logloss', use_label_encoder=False, random_state=seed)
#       5 results_xgb = cross_val_score(model_xgb, X, y, cv=kfold)
#       6 print(f"XGBoost Accuracy: {results_xgb.mean():.4f} ({results_xgb.std():.4f})")
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# ### 8. Primeros resultados
# Crea un dataframe con los resultados y sus algoritmos, ordenándolos de mayor a menor

# %%
resultados = pd.DataFrame({
    'Modelo': ['Bagging', 'Random Forest', 'AdaBoost', 'Gradient Boosting', 'XGBoost'],
    'Accuracy Mean': [results_bagging.mean(), results_rf.mean(), results_ada.mean(), results_gb.mean(), results_xgb.mean()],
    'Std': [results_bagging.std(), results_rf.std(), results_ada.std(), results_gb.std(), results_xgb.std()]})

# Ordenamos de mayor a menor accuracy
resultados_ordenados = resultados.sort_values(by='Accuracy Mean', ascending=False)
resultados_ordenados
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 resultados = pd.DataFrame({
#       2     'Modelo': ['Bagging', 'Random Forest', 'AdaBoost', 'Gradient Boosting', 'XGBoost'],
# ----> 3     'Accuracy Mean': [results_bagging.mean(), results_rf.mean(), results_ada.mean(), results_gb.mean(), results_xgb.mean()],
#       4     'Std': [results_bagging.std(), results_rf.std(), results_ada.std(), results_gb.std(), results_xgb.std()]})
#       6 # Ordenamos de mayor a menor accuracy
#       7 resultados_ordenados = resultados.sort_values(by='Accuracy Mean', ascending=False)
#
# NameError: name 'results_xgb' is not defined

# %% [markdown]
# ### 9. Hiperparametrización
# Vuelve a entrenar los modelos de nuevo, pero esta vez dividiendo el conjunto de datos en train/test y utilizando un gridsearch para encontrar los mejores hiperparámetros.

# %%
# 1. División Train/Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)


params_rf = {'n_estimators': [50, 100, 200],'max_features': [2, 3, 4],'max_depth': [None, 10, 20]}

grid_rf = GridSearchCV(estimator=RandomForestClassifier(random_state=seed),
                       param_grid=params_rf,
                       cv=5,
                       scoring='accuracy')

grid_rf.fit(X_train, y_train)

# --- Tuning XGBoost ---

params_xgb = {'n_estimators': [50, 100],'learning_rate': [0.01, 0.1, 0.2],'max_depth': [3, 5]}

grid_xgb = GridSearchCV(estimator=XGBClassifier(eval_metric='logloss', use_label_encoder=False, random_state=seed),
                        param_grid=params_xgb,
                        cv=5,
                        scoring='accuracy')

grid_xgb.fit(X_train, y_train)

print(f"Mejor RF: {grid_rf.best_score_:.4f} con params {grid_rf.best_params_}")
print(f"Mejor XGB: {grid_xgb.best_score_:.4f} con params {grid_xgb.best_params_}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 15
#       5 params_rf = {
#       6     'n_estimators': [50, 100, 200],
#       7     'max_features': [2, 3, 4],
#       8     'max_depth': [None, 10, 20]}
#      10 grid_rf = GridSearchCV(estimator=RandomForestClassifier(random_state=seed),
#      11                        param_grid=params_rf,
#      12                        cv=5,
#      13                        scoring='accuracy')
# ---> 15 grid_rf.fit(X_train, y_train)
#      17 # --- Tuning XGBoost ---
#      18 params_xgb = {
#      19     'n_estimators': [50, 100],
#      20     'learning_rate': [0.01, 0.1, 0.2],
#      21     'max_depth': [3, 5]}
#
# File c:\Users\mikel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
# ...

# %% [markdown]
# ### 10. Conclusiones finales

# %% [markdown]
# Escogemos el modelo que mejor generalice, es decir, el que tenga mejor métrica ante test (RF hiperparametrizado)

# %%
# Supongamos que el mejor fue Random Forest (basado en el grid search anterior)
best_model = grid_rf.best_estimator_

# Predicción final sobre test
accuracy_test = best_model.score(X_test, y_test)

print("--- CONCLUSIÓN FINAL ---")
print(f"El modelo seleccionado es: {type(best_model).__name__}")
print(f"Hiperparámetros óptimos: {grid_rf.best_params_}")
print(f"Accuracy final en Test Set: {accuracy_test:.2%}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Supongamos que el mejor fue Random Forest (basado en el grid search anterior)
# ----> 2 best_model = grid_rf.best_estimator_
#       4 # Predicción final sobre test
#       5 accuracy_test = best_model.score(X_test, y_test)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'
