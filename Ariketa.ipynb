# %%
import seaborn as sns

sns.heatmap

# %%
X = df.drop(columns=["actual"])
y = df["actual"]

# %%
drt = DessicionTreeRegeresor(max_depth=2)
drt.fit(X_train,y_train)

pred= drt.predict(X_test)

metrics.mean_absolute_error(y_test,pred)

# %%
gs= GrindSearch(estimator=drt, param_grid= lista, cv=4)
